# %%
# !rm -rf smoothquant
# !git clone https://github.com/mit-han-lab/smoothquant.git
# Out:
# Cloning into 'smoothquant'...
# remote: Enumerating objects: 352, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 352 (delta 120), reused 91 (delta 91), pack-reused 183 (from 1)
# Receiving objects: 100% (352/352), 6.80 MiB | 11.51 MiB/s, done.
# Resolving deltas: 100% (202/202), done.

# %%
# %cd smoothquant/
# !pip install -e .
# !pip install transformers==4.36.0 accelerate datasets zstandard

# 3. (Optional) Verify torch + cuda
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# /content/smoothquant
# Obtaining file:///content/smoothquant
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for smoothquant
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 89.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 109.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !python setup.py install
# %cd ..
# Out:
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
# ...

# %%
# !mkdir -p /content/smoothquant/dataset

# !wget https://huggingface.co/datasets/mit-han-lab/pile-val-backup/resolve/main/val.jsonl.zst -O /content/smoothquant/dataset/val.jsonl.zst
# Out:
# --2025-10-29 07:10:08--  https://huggingface.co/datasets/mit-han-lab/pile-val-backup/resolve/main/val.jsonl.zst
# Resolving huggingface.co (huggingface.co)... 18.238.109.52, 18.238.109.92, 18.238.109.121, ...
# Connecting to huggingface.co (huggingface.co)|18.238.109.52|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !ls -lh /content/smoothquant/dataset
# Out:
# total 450M
# -rw-r--r-- 1 root root 450M Oct 29 07:10 val.jsonl.zst

# %%
# !python /content/smoothquant/examples/generate_act_scales.py \
    --model-name facebook/opt-1.3b \
    --output-path /content/smoothquant/act_scales/opt-1.3b.pt \
    --num-samples 128 \
    --seq-len 2048 \
    --dataset-path /content/smoothquant/dataset/val.jsonl.zst
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json: 100% 685/685 [00:00<00:00, 6.17MB/s]
# config.json: 100% 653/653 [00:00<00:00, 5.83MB/s]
# vocab.json: 899kB [00:00, 40.7MB/s]
# merges.txt: 456kB [00:00, 116MB/s]
# special_tokens_map.json: 100% 441/441 [00:00<00:00, 5.20MB/s]
# ...

# %%
python examples/generate_act_scales.py \
    --model-name facebook/opt-2.7b \
    --output-path act_scales/opt-2.7b.pt \
    --num-samples 512 \
    --seq-len 2048 \
    --dataset-path dataset/val.jsonl.zst

# %%
# !python /content/smoothquant/smoothquant/ppl_eval.py \
    --model_path facebook/opt-1.3b \
    --act_scales_path /content/smoothquant/act_scales/opt-1.3b.pt \
    --smooth \
    --alpha 0.5 \
    --quantize
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...
